# %%
import matplotlib.pyplot as plt
import networkx as nx
graph = nx.complete_graph(10)
nx.draw(graph)

# %%
#!pip install binarytree
import binarytree
from binarytree import bst
tree = bst(height = 5, is_perfect = False)
print(tree)
# Out:
#                                ______________________48_______________
#                               /                                       \
#                    __________36______                     _____________54
#                   /                  \                   /               \
#        __________32                  _39_________       49______          55___
#       /            \                /            \              \              \
#     _17___          33            _38         ____47            _52            _57___
#    /      \           \          /           /                 /   \          /      \
#   16      _30          34       37         _44               _51    53       56      _59
#  /       /   \           \                /   \             /                       /   \
# 9       18    31          35             41    46          50                      58    60

# %%
graph = {
    'A' : ['B','C'],
    'B' : ['D', 'E'],
    'C' : ['F'],
    'D' : [],
    'E' : ['F'],
    'F' : []
}
visited = set() 
def df(visited, graph, node):
    if node not in visited:
        print (node)
        visited.add(node)
        for neighbour in graph[node]:
            dfs(visited, graph, neighbour)

df(visited, graph, 'A')
# Out:
# A
# B
# D
# E
# F
# C
